# %%
#Importing requests 
import requests
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import sys
import requests
import json
import logging
import time
logging.captureWarnings(True)

  
# Making a get request
response = requests.get('https://stoplight.io/mocks/proptrack/property-data-apis/99896681/api/v2/market/sale/historic/sale-transaction-volume?propertyTypes=house&state=vic&postcode=3800&suburb=Clayton')
  
# print request object to get the status code
print(response)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;Response [200]&gt;
# </div>

# %%
# Content of the the variable
type(response.content)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: bytes</div>

# %%
# Content of the the status code
response.status_code
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 200</div>

# %%
# trying to convert the json to dictionary with key as attribute and value as the value
response_dict = response.json()
length(response_dict)
for i in response_dict:
    print("key: ", i, "val: ", response_dict[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# ...

# %%
#Displaying the dict
response_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: [{&#39;propertyType&#39;: &#39;house&#39;,
#   &#39;dateRanges&#39;: [{&#39;startDate&#39;: &#39;2021-09-01&#39;,
#     &#39;endDate&#39;: &#39;2022-08-31&#39;,
#     &#39;metricValues&#39;: [{&#39;bedrooms&#39;: &#39;1&#39;, &#39;value&#39;: 10},
#      {&#39;bedrooms&#39;: &#39;2&#39;, &#39;value&#39;: 11},
#      {&#39;bedrooms&#39;: &#39;3&#39;, &#39;value&#39;: 18},
#      {&#39;bedrooms&#39;: &#39;4&#39;, &#39;value&#39;: 24},
#      {&#39;bedrooms&#39;: &#39;5+&#39;, &#39;value&#39;: 14}]}]},
#  {&#39;propertyType&#39;: &#39;unit&#39;,
#   &#39;dateRanges&#39;: [{&#39;startDate&#39;: &#39;2021-09-01&#39;,
# ...

# %%
# Generating the token using the mock server 
import http.client

conn = http.client.HTTPSConnection("stoplight.io")

payload = "grant_type=client_credentials"

headers = {
    'Content-Type': "application/x-www-form-urlencoded",
    'Authorization': "Basic 33691khei9lg0fdr6aijri3l9l:lvsnu0nhn57tmevf3u7bmt0l8u4oq9csgslr77iqv9sijrb8826" 
    }

conn.request("POST", "/mocks/proptrack/property-data-apis/70243931/oauth2/token", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;access_token&#34;:&#34;eyJrarY0doWW9nWmJJXC9FQWlrZXNuWUk9IiwiYWxnIjoiUlMyNTYifQ.eyJzdWIiOiI2c2QxNGVpNTVkazg1OWxjcG4yZ2tnM2JuYyIsInRva2VuX3VzZSI6ImFjY2VzcyIsInNjb3BlIjoic_lLWFw&#34;,&#34;token_type&#34;:&#34;Bearer&#34;,&#34;expires_in&#34;:3600}
# </div>

# %%
import requests

url = "https://stoplight.io/mocks/proptrack/property-data-apis/67669715/api/v2/properties/12345612/listings"

querystring = {"latestListingOnly":"true","listingType":"sale","status":"current"}

headers = {
    "Content-Type": "application/json",
    "Authorization": "eyJrarY0doWW9nWmJJXC9FQWlrZXNuWUk9IiwiYWxnIjoiUlMyNTYifQ.eyJzdWIiOiI2c2QxNGVpNTVkazg1OWxjcG4yZ2tnM2JuYyIsInRva2VuX3VzZSI6ImFjY2VzcyIsInNjb3BlIjoic_lLWFw",
    "Prefer": "code=200"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
#To get the code after Basic encode credentials to base64 with input(client_id:client_secret)
#To get the token for live server
import requests

url = "https://data.proptrack.com/oauth2/token"

payload = "grant_type=client_credentials"
headers = {
    "Content-Type": "application/x-www-form-urlencoded",
    "Authorization": "Basic MzM2OTFraGVpOWxnMGZkcjZhaWpyaTNsOWw6bHZzbnUwbmhuNTd0bWV2ZjN1N2JtdDBsOHU0b3E5Y3Nnc2xyNzdpcXY5c2lqcmI4ODI2"
}

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#             {
#               &#34;access_token&#34;:  &#34;eyJraWQiOiJiYWRmNzUyNC1jYzBkLTQ3YWUtYTAzMC02MjBlYTE3ZDNlZjMiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....aUzbwAnnTvNUuxCHO4SNYeawDU065174tPnvspMrUa5ppqaKFVvQBI8siBoXrXWzkaVDGuWtSNhUNdpAJc9UdAXzETE3Ac-K2LpN7oQYVc08FVSno2HJgX6uIX_hbJzGPnwO8_pMoWy11_KpTpk7zQZRQ8mimcDt_2FtbADZYCk22lZVga78kH08e7Gm5rOqlbOEk1N4WRG_kFSK7dmta4iDv7oWkzBX5Bk4Dr6PTHpd8e7D6qUKarHRvYxM2CcqPy3EruanVHa9nitrmbbL1iqPlw3aB7zMd8LpPKoZz_cFULW24N0Nmaqp_xY1aJfWg75pL6KB2jq088T1ndAyrQ&#34;,
#               &#34;token_type&#34;: &#34;Bearer&#34;,
#               &#34;expires_in&#34;: 3600
#             }
#
#
# </div>

# %%
import requests

url = "https://stoplight.io/mocks/proptrack/property-data-apis/99896681/api/v2/market/supply-and-demand/potential-buyers"

querystring = {"state":"vic","postcode":"3168","suburb":"Clayton","propertyTypes":"house"}

headers = {
    "Content-Type": "application/json",
    "Prefer": "code=200, dynamic=true"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
# Matching for address in the data
import http.client

conn = http.client.HTTPSConnection("data.proptrack.com")

headers = {
    'Content-Type': "application/json",
    'Authorization': "Bearer eyJraWQiOiJiYWRmNzUyNC1jYzBkLTQ3YWUtYTAzMC02MjBlYTE3ZDNlZjMiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....aUzbwAnnTvNUuxCHO4SNYeawDU065174tPnvspMrUa5ppqaKFVvQBI8siBoXrXWzkaVDGuWtSNhUNdpAJc9UdAXzETE3Ac-K2LpN7oQYVc08FVSno2HJgX6uIX_hbJzGPnwO8_pMoWy11_KpTpk7zQZRQ8mimcDt_2FtbADZYCk22lZVga78kH08e7Gm5rOqlbOEk1N4WRG_kFSK7dmta4iDv7oWkzBX5Bk4Dr6PTHpd8e7D6qUKarHRvYxM2CcqPy3EruanVHa9nitrmbbL1iqPlw3aB7zMd8LpPKoZz_cFULW24N0Nmaqp_xY1aJfWg75pL6KB2jq088T1ndAyrQ"
    }

conn.request("GET", "/api/v2/address/match?q=gardner", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{
#           &#34;errors&#34;: [
#             {
#               &#34;code&#34;: 7002,
#               &#34;level&#34;: &#34;CRITICAL&#34;,
#               &#34;description&#34;: &#34;Address cannot be matched, the address entered does not match a single property within our system - Please consider revising the address query parameter&#34;
#             }
#           ]
#         }
# </div>

# %%
#Getting real time data property ID: 2134524
import requests

url = "https://data.proptrack.com/api/v2/properties/2134524/listings"

headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer eyJraWQiOiJiYWRmNzUyNC1jYzBkLTQ3YWUtYTAzMC02MjBlYTE3ZDNlZjMiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....aUzbwAnnTvNUuxCHO4SNYeawDU065174tPnvspMrUa5ppqaKFVvQBI8siBoXrXWzkaVDGuWtSNhUNdpAJc9UdAXzETE3Ac-K2LpN7oQYVc08FVSno2HJgX6uIX_hbJzGPnwO8_pMoWy11_KpTpk7zQZRQ8mimcDt_2FtbADZYCk22lZVga78kH08e7Gm5rOqlbOEk1N4WRG_kFSK7dmta4iDv7oWkzBX5Bk4Dr6PTHpd8e7D6qUKarHRvYxM2CcqPy3EruanVHa9nitrmbbL1iqPlw3aB7zMd8LpPKoZz_cFULW24N0Nmaqp_xY1aJfWg75pL6KB2jq088T1ndAyrQ"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# ...
